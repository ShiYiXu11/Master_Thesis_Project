# %%
from huggingface_hub import snapshot_download

model_path = snapshot_download(
    repo_id="meta-llama/Meta-Llama-3.1-70B",  
    cache_dir="models",           
    local_dir="models/Llama-3.1-70B", 
    local_dir_use_symlinks=False         
)

print("downloaded", model_path)
# Out:
# Fetching 50 files:   0%|          | 0/50 [00:00<?, ?it/s]
# original/consolidated.00.pth:   0%|          | 0.00/17.6G [00:00<?, ?B/s]
# original/consolidated.02.pth:   0%|          | 0.00/17.6G [00:00<?, ?B/s]
# original/consolidated.03.pth:   0%|          | 0.00/17.6G [00:00<?, ?B/s]
# original/consolidated.01.pth:   0%|          | 0.00/17.6G [00:00<?, ?B/s]
# original/consolidated.04.pth:   0%|          | 0.00/17.6G [00:00<?, ?B/s]
# original/consolidated.05.pth:   0%|          | 0.00/17.6G [00:00<?, ?B/s]
# original/consolidated.06.pth:   0%|          | 0.00/17.6G [00:00<?, ?B/s]
# model-00001-of-00030.safetensors:   0%|          | 0.00/4.58G [00:00<?, ?B/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File /work/shiyxu/myenv/lib64/python3.9/site-packages/tqdm/contrib/concurrent.py:51, in _executor_map(PoolExecutor, fn, *iterables, **tqdm_kwargs)
# ...

# %%
from datasets import load_dataset, load_from_disk

# 1. Your existing code to load the dataset
# (Using a sample Parquet file for this example)
data_files = {
    "Rebel_train_0000": "https://huggingface.co/datasets/Babelscape/rebel-dataset/resolve/refs%2Fconvert%2Fparquet/REBEL/train/0001.parquet"
}
dataset = load_dataset("parquet", data_files=data_files)

# 2. Define a path to save the dataset locally
local_path = "data/triplets/"

# 3. Save the dataset to the specified path 💾
dataset.save_to_disk(local_path)

print(f"Dataset saved to {local_path}")
# Out:
# ---------------------------------------------------------------------------
# ArrowInvalid                              Traceback (most recent call last)
# Cell In[4], line 8
#       3 # 1. Your existing code to load the dataset
#       4 # (Using a sample Parquet file for this example)
#       5 data_files = {
#       6     "Rebel_train_0000": "https://huggingface.co/datasets/martinjosifoski/SynthIE/blob/refs%2Fconvert%2Fparquet/rebel/train/0000.parquet"
#       7 }
# ----> 8 dataset = load_dataset("parquet", data_files=data_files)
#      10 # 2. Define a path to save the dataset locally
#      11 local_path = "data/triplets/"
#
# File /work/shiyxu/myenv/lib64/python3.9/site-packages/datasets/load.py:2084, in load_dataset(path, name, data_dir, data_files, split, cache_dir, features, download_config, download_mode, verification_mode, keep_in_memory, save_infos, revision, token, streaming, num_proc, storage_options, trust_remote_code, **config_kwargs)
# ...

# %%
dataset = load_from_disk("data/triplets/Rebel_train_0000")
df=dataset.to_pandas()
df.head(5)
# Out:
#            id                              title  \
# 0  Q7185360-1   Philippine one hundred-peso note
# 1  Q7185360-2   Philippine one hundred-peso note
# 2  Q7185306-1  Philippine five hundred-peso note
# 3  Q7185306-3  Philippine five hundred-peso note
# 4  Q7185363-1  Philippine one thousand-peso note
#
#                                              context  \
# 0  The Philippine one hundred-peso note ( Filipin...
# 1  Philippine president Manuel A . Roxas is curre...
# 2  The Philippine five hundred-peso note ( Filipi...
# 3  and his wife , President Corazon Aquino are cu...
# 4  The Philippine one thousand-peso note ( Filipi...
#
#                                             triplets
# 0  <triplet> Philippine one hundred-peso note <su...
# 1  <triplet> Manuel A. Roxas <subj> Philippine pr...
# 2  <triplet> Philippine five hundred-peso note <s...
# 3  <triplet> Corazon Aquino <subj> President <obj...
# 4  <triplet> Philippine one thousand-peso note <s...

# %%
from datasets import load_dataset, load_from_disk

# 1. Your existing code to load the dataset
# (Using a sample Parquet file for this example)
data_files = {
    "Rebel_experiment": "https://huggingface.co/datasets/martinjosifoski/SynthIE/blob/refs%2Fconvert%2Fparquet/rebel/train/0001.parquet"
}
dataset = load_dataset("parquet", data_files=data_files)

# 2. Define a path to save the dataset locally
local_path = "triplets/"

# 3. Save the dataset to the specified path 💾
dataset.save_to_disk(local_path)

print(f"Dataset saved to {local_path}")
# Out:
# ...
# ---------------------------------------------------------------------------
# ArrowInvalid                              Traceback (most recent call last)
# Cell In[2], line 8
#       3 # 1. Your existing code to load the dataset
#       4 # (Using a sample Parquet file for this example)
#       5 data_files = {
#       6     "Rebel_experiment": "https://huggingface.co/datasets/martinjosifoski/SynthIE/blob/refs%2Fconvert%2Fparquet/rebel/train/0001.parquet"
#       7 }
# ----> 8 dataset = load_dataset("parquet", data_files=data_files)
#      10 # 2. Define a path to save the dataset locally
#      11 local_path = "triplets/"
#
# File /work/shiyxu/myenv/lib64/python3.9/site-packages/datasets/load.py:2084, in load_dataset(path, name, data_dir, data_files, split, cache_dir, features, download_config, download_mode, verification_mode, keep_in_memory, save_infos, revision, token, streaming, num_proc, storage_options, trust_remote_code, **config_kwargs)
# ...

# %%
dataset = load_from_disk("triplets/SynthIE_text_test")
df=dataset.to_pandas()
df.head(5)
# Out:
#       id                                               text  \
# 0  18997  Pickin' Up the Pieces (Fitz and the Tantrums a...
# 1  44171  Primarily Jazz was recorded at Fullerton College.
# 2  49548  Njombe Region is an instance of a region in Ta...
# 3  49269  Konstadinos Anastasiou is a Greek athlete, spe...
# 4    856  Harold Schwartz is a human who is a citizen of...
#
#                                             triplets  \
# 0  [{'subject': '{'surfaceform': "Pickin'_Up_the_...
# 1  [{'subject': '{'surfaceform': 'Primarily_Jazz'...
# 2  [{'subject': '{'surfaceform': 'Njombe_Region',...
# 3  [{'subject': '{'surfaceform': 'Konstadinos_Ana...
# 4  [{'subject': '{'surfaceform': 'Harold_Schwartz...
#
#                                             entities  \
# 0  [{'surfaceform': 'Pickin'_Up_the_Pieces_(Fitz_...
# 1  [{'surfaceform': 'Primarily_Jazz', 'uri': 'Q72...
# 2  [{'surfaceform': 'Njombe_Region', 'uri': 'Q208...
# 3  [{'surfaceform': 'Konstadinos_Anastasiou', 'ur...
# ...
